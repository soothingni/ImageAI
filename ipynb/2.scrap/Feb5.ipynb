# %% [markdown]
# # Day1. Basic Image

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading https://files.pythonhosted.org/packages/68/81/20771fab16b8ccd5f642a44ef355e274075754dc002b5d6f6e9779e715d8/opencv_python-4.2.0.32-cp37-cp37m-macosx_10_9_x86_64.whl (47.9MB)
#      |████████████████████████████████| 47.9MB 754kB/s eta 0:00:01     |█████████                       | 13.6MB 614kB/s eta 0:00:56     |███████████████████████████     | 40.4MB 563kB/s eta 0:00:14
# Requirement already satisfied: numpy>=1.14.5 in /Users/soothingni/anaconda3/lib/python3.7/site-packages (from opencv-python) (1.17.4)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.2.0.32
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from PIL import Image

# %%
a = np.asarray([
    [0, 0, 0, 0],
    [127, 127, 127, 127],
    [200, 200, 200, 200],
    [255, 255, 255, 255]
], dtype = 'uint8')

plt.imshow(a)

# %%
plt.imshow(a, cmap = 'gray')

# %%
b = a + 5

print(b)
plt.imshow(b, cmap = 'gray')
# Out:
# [[  5   5   5   5]
#  [132 132 132 132]
#  [205 205 205 205]
#  [  4   4   4   4]]

# %%
a = np.array([
    [255, 255, 255, 255],
    [0, 0, 0, 0],
    [0, 0, 0, 0],
    [255, 255, 255, 255]
], dtype = 'uint8')

plt.imshow(a, cmap = 'gray')

# %%
b = np.array([
    [255, 255, 255, 255],
    [0, 0, 0, 0],
    [0, 0, 0, 0],
    [255, 255, 255, 255]
])

plt.imshow(b, cmap = 'gray')

# %%
r = np.array([
    [255, 255, 255, 255],
    [0, 0, 0, 0],
    [0, 0, 0, 0],
    [255, 255, 255, 255]
], dtype = 'uint8')

g = np.array([
    [0, 0, 0, 0],
    [255, 255, 255, 255],
    [0, 0, 0, 0],
    [255, 255, 255, 255]
], dtype = 'uint8')

b = np.array([
    [0, 0, 0, 0],
    [0, 0, 0, 0],
    [255, 255, 255, 255],
    [0, 0, 0, 0] 
], dtype = 'uint8')

colors = np.dstack([r, g, b])
plt.imshow(colors)
print(colors.shape)
# Out:
# (4, 4, 3)

# %%
plt.imshow(r)

# %%
z = np.zeros((4, 4), dtype = 'uint8')

plt.imshow(np.dstack([r, z, z]))
plt.show()

plt.imshow(np.dstack([z, g, z]))
plt.show()

plt.imshow(np.dstack([z, z, b]))
plt.show()

# %%
img = cv2.imread('friends.jpg')
print(type(img))
print(img.shape)

plt.imshow(img)
# Out:
# <class 'numpy.ndarray'>
# (1600, 1600, 3)

# %%
b = img[:, :, 0]
g = img[:, :, 1]
r = img[:, :, 2]

rgb = np.dstack([r, g, b])

plt.imshow(rgb)

# %%
r += 30
g += 30

rgb = np.dstack([r, g, b])

plt.imshow(rgb)

# %%
img = cv2.imread('friends.jpg')
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img2)

# %%
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

h = hsv[:, :, 0]
s = hsv[:, :, 1]
v = hsv[:, :, 2]

result = img.copy()
print(result.shape)
print(result.shape[0])
# Out:
# (1600, 1600, 3)
# 1600

# %%
print(hsv)
# Out:
# [[[ 16  26 149]
#   [ 16  26 149]
#   [ 16  26 149]
#   ...
#   [113  65 216]
#   [113  65 216]
#   [113  65 217]]
#
#  [[ 16  26 149]
#   [ 16  26 149]
#   [ 16  26 149]
#   ...
#   [113  65 216]
#   [113  65 216]
#   [113  65 216]]
#
#  [[ 18  29 149]
#   [ 18  29 149]
#   [ 18  29 149]
#   ...
#   [112  66 216]
#   [113  65 216]
#   [113  65 216]]
#
#  ...
#
#  [[101  95 193]
#   [101  90 204]
#   [101  89 210]
#   ...
#   [ 15 152 111]
#   [ 15 144 113]
#   [ 14 148 107]]
#
#  [[102  96 194]
#   [102  95 199]
#   [101  93 206]
#   ...
#   [ 14 154 111]
#   [ 14 144 115]
#   [ 14 149 111]]
#
#  [[103 102 188]
#   [102 103 189]
#   [102  97 200]
#   ...
#   [ 15 160 110]
#   [ 13 146 115]
#   [ 13 150 112]]]

# %%
print(h)
# Out:
# [[ 16  16  16 ... 113 113 113]
#  [ 16  16  16 ... 113 113 113]
#  [ 18  18  18 ... 112 113 113]
#  ...
#  [101 101 101 ...  15  15  14]
#  [102 102 101 ...  14  14  14]
#  [103 102 102 ...  15  13  13]]

# %%
plt.imshow(hsv)

# %%
for r in range(h.shape[0]):
    for c in range(h.shape[1]):
        col = (img[r, c, 0] + img[r, c, 1] + img[r, c, 2]) / 3
        result[r, c, 0] = col
        result[r, c, 1] = col
        result[r, c, 2] = col
    
plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
# Out:
# /Users/soothingni/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: overflow encountered in ubyte_scalars
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for r in range(h.shape[0]):
    for c in range(h.shape[1]):
        col = (int(img[r, c, 0]) + img[r, c, 1] + img[r, c, 2]) / 3
        result[r, c, 0] = col
        result[r, c, 1] = col
        result[r, c, 2] = col
    
plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (1600, 1600, 3)

# %%
h.shape
# Out:
# (1600, 1600)

# %%
result = img.copy()

for r in range(h.shape[0]):
    for c in range(h.shape[1]):
        if h[r, c] >= 0 and h[r, c] <= 20:
            result[r, c, :] = img[r, c, :]
        else:
            result[r, c, :] = 0
            
plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))

# %%
lower = np.array([0, 48, 80], dtype = 'uint8')
upper = np.array([20, 255, 255], dtype = 'uint8')

for r in range(h.shape[0]):
    for c in range(h.shape[1]):
        bH = h[r, c] >= 0 and h[r, c] <= 20
        bS = s[r, c] >= 48 and s[r, c] <= 255
        bV = v[r, c] >= 80 and v[r, c] <= 255
        if bH and bS and bV:
            result[r, c, :] = img[r, c, :]
        else:
            result[r, c, :] = 0
            
plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))

# %%
mask = img.copy()

for r in range(h.shape[0]):
    for c in range(h.shape[1]):
        bH = h[r, c] >= 0 and h[r, c] <= 20
        bS = s[r, c] >= 48 and s[r, c] <= 255
        bV = v[r, c] >= 80 and v[r, c] <= 255
        if bH and bS and bV:
            mask[r, c, :] = 255
        else:
            mask[r, c, :] = 0
            
plt.imshow(cv2.cvtColor(mask, cv2.COLOR_BGR2RGB))

# %%
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
result_rgb = cv2.cvtColor(result, cv2.COLOR_BGR2RGB)

all = np.hstack([rgb, result_rgb, mask])

plt.imshow(all)

# %%
b, g, r = cv2.split(img)

plt.hist(b.ravel(), 256, [0, 256], color = 'b')
plt.hist(g.ravel(), 256, [0, 256], color = 'g')
plt.hist(r.ravel(), 256, [0, 256], color = 'r')
plt.show()

# %%
h, s, v = cv2.split(cv2.cvtColor(img, cv2.COLOR_BGR2HSV))

plt.hist(h.ravel(), 256, [0, 256], color = 'b')
plt.hist(s.ravel(), 256, [0, 256], color = 'g')
plt.hist(v.ravel(), 256, [0, 256], color = 'r')
plt.show()
