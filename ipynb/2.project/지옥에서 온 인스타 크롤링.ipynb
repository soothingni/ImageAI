# %%
pip install selenium

# %%
handle = 'sunnydopia@live.co.kr' #인스타그램 아이디
pwd = '*helloimys90'  #인스타그램 비밀번호
keyword= '성수'   #검색할 키워드
num_of_pages = 100 #몇 번 스크롤 할 건지; 200 --> 1730개 게시글 긁어짐

# %%
#함수 정의
from selenium import webdriver
from urllib.parse import quote
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd 
import re

#URL 가져오기
def InstagramUrlFromKeyword (browser,keyword,num_of_pagedowns):
    keyword_url_encode=quote(keyword)
    url='https://www.instagram.com/explore/tags/'+keyword+'/?hl=ko'
    browser.get(url)
    time.sleep(3)
    login = browser.find_element_by_xpath('//*[@id="react-root"]/section/nav/div[2]/div/div/div[3]/div/span/a[1]/button')
    login.click()
    time.sleep(3)
    user_id = browser.find_element_by_class_name('_2hvTZ.pexuQ.zyHYP')
    pw = browser.find_element_by_xpath('//*[@id="react-root"]/section/main/div/article/div/div[1]/div/form/div[3]/div/label/input')
    user_id.send_keys(handle)
    pw.send_keys(pwd)
    button = browser.find_element_by_xpath('//*[@id="react-root"]/section/main/div/article/div/div[1]/div/form/div[4]/button')
    button.click()
    time.sleep(3)
    arr_href=[]
    body=browser.find_element_by_tag_name('body')
    for i in range(num_of_pagedowns):
        body.send_keys(Keys.PAGE_DOWN)
        time.sleep(1)
        post=browser.find_elements_by_class_name('v1Nh3')
        for j in post:
            href_str=j.find_element_by_css_selector('a').get_attribute('href')
            arr_href.append(href_str)
    return set(arr_href)    

char = r'#[\d\w]+'
char2 = re.compile('[^ 0-9a-zA-Zㄱ-ㅣ가-힣!#?]')

#URL에서 데이터 가져오기
def IdHashTagFromInstagram(browser,url):
    browser.get(url)
    
    datetime = browser.find_element_by_class_name('_1o9PC.Nzb55').get_attribute('title')
    href=browser.find_elements_by_class_name('C4VMK')
    #포스트 내용(글, 태그)
    total_hash_text=[]    
    for i in range(0, len(href)):
        hash_text= href[i].find_element_by_css_selector('span').text
        total_hash_text.append(hash_text)
    tags = re.findall(char, char2.sub(' ',str(total_hash_text)))
    
    return datetime, tags

# %%
#크롤링
browser= webdriver.Chrome()
arr=InstagramUrlFromKeyword(browser,keyword,num_of_pages)
insta_df=pd.DataFrame(columns = {'Datetime', 'Tags'})

for url in arr:
        try:
            datetime, tags = IdHashTagFromInstagram(browser,url)
            insta_df = insta_df.append({'Datetime': datetime, 'Tags': tags}, ignore_index = True)
        except:
            continue

# %%
insta_df
# Out:
#           Datetime                                               Tags
# 0    2019년 12월 23일  [#tattoo, #타투, #낙서타투, #미니타투, #일러스트타투, #칼라타투, #...
# 1    2019년 12월 24일  [#tattoo, #newschooltattoo, #oldschooltattoo, ...
# 2    2019년 12월 24일  [#성수카페, #서울숲카페, #성수, #서울숲, #카페, #카페그램, #디저트, #...
# 3    2019년 12월 23일                                                 []
# 4    2019년 12월 24일  [#성수, #서울숲스냅, #마리에블룸, #travel, #travelgram, #p...
# ..             ...                                                ...
# 772  2019년 12월 23일                                                 []
# 773  2019년 12월 24일                                           [#아모레성수]
# 774  2019년 12월 23일  [#성수, #카페, #헬린이, #헬린이그램, #운동하는여자, #운동, #운동그램, ...
# 775  2019년 12월 23일  [#비커즈, #킹덤즈, #오루트, #Because, #Becz, #Kingdoms,...
# 776  2019년 12월 24일  [#성수, #서울숲, #문스페이스스타, #달공별, #moonspacestar, #뱅...
#
# [777 rows x 2 columns]

# %%
from collections import Counter

# %%
insta_str = []
for tags in insta_df['Tags']:
    insta_str.extend(tags)

# %%
insta_str
# Out:
# ['#tattoo',
#  '#타투',
#  '#낙서타투',
#  '#미니타투',
#  '#일러스트타투',
#  '#칼라타투',
#  '#드로잉타투',
#  '#성수역',
#  '#성수',
#  '#타투도안',
#  '#미니멀타투',
#  '#귀여운타투',
#  '#캐릭터타투',
#  '#크레용타투',
#  '#크레용',
#  '#크레파스',
#  '#우정타투',
#  '#커플타투',
#  '#팔타투',
#  '#팔뚝타투',
#  '#스마일타투',
#  '#스마일',
#  '#tattoo',
#  '#newschooltattoo',
#  '#oldschooltattoo',
#  '#linetattoo',
#  '#colortattoo',
#  '#drawing',
#  '#design',
#  '#irezumi',
#  '#orientaltattoo',
#  '#타투',
#  '#문신',
#  '#문신도안',
#  '#타투도안',
#  '#라인타투',
#  '#미니타투',
#  '#올드스쿨타투',
#  '#건대타투',
#  '#서울타투',
#  '#감성타투',
#  '#성수',
#  '#건대',
#  '#성수카페',
#  '#서울숲카페',
#  '#성수',
#  '#서울숲',
#  '#카페',
#  '#카페그램',
#  '#디저트',
#  '#쑥라떼',
#  '#임자있슈',
#  '#흑임자티라미슈',
#  '#앙트리',
#  '#양갱',
#  '#cafe',
#  '#cafegram',
#  '#dessert',
#  '#묘사서울',
#  '#pure',
#  '#성수',
#  '#서울숲스냅',
#  '#마리에블룸',
#  '#travel',
#  '#travelgram',
#  '#photo',
#  '#iphone7plus',
#  '#photography',
#  '#selfies',
#  '#selfie',
#  '#selstagram',
#  '#wandering',
#  '#성수',
#  '#성수맛집',
#  '#성수술집',
#  '#바베양장',
#  '#미쉐린가이드',
#  '#성수',
#  '#대림창고',
#  '#서울',
#  '#성수',
#  '#뚝섬',
#  '#신도림',
#  '#영등포',
#  '#소주',
#  '#주말',
#  '#백두산',
#  '#영화',
#  '#데이트',
#  '#커플',
#  '#인스타그램',
#  '#사진',
#  '#좋아요',
#  '#맛점',
#  '#식스타',
#  '#식스타그램',
#  '#음식',
#  '#점심',
#  '#저녘',
#  '#피자',
#  '#피맥',
#  '#양쥬',
#  '#양식',
#  '#쿠킹스타그램',
#  '#쿠킹',
#  '#홈메이드',
#  '#홈쿠킹',
#  '#야식',
#  '#분위기맛집',
#  '#이태원',
#  '#경리단길',
#  '#강남',
#  '#홍대',
#  '#성수',
#  '#교대',
#  '#쿠킹클래스',
#  '#성수연방',
#  '#아크앤북',
#  '#일요일',
#  '#행사',
#  '#성수',
#  '#성수동',
#  '#성수핫플',
#  '#성수동카페',
#  '#성수역',
#  '#성수카페',
#  '#성수투어',
#  '#성수',
#  '#뮤지엄오브컬러',
#  '#colors',
#  '#dreamers',
#  '#핑크핑크',
#  '#비커즈',
#  '#박성수',
#  '#성수',
#  '#홍대',
#  '#버스킹',
#  '#비커즈콘서트',
#  '#191215',
#  '#ootd',
#  '#daily',
#  '#selfie',
#  '#성수',
#  '#merrychristmas',
#  '#오늘도온화하게',
#  '#성수카페',
#  '#서울숲카페',
#  '#성수',
#  '#서울숲',
#  '#카페',
#  '#카페그램',
#  '#디저트',
#  '#쑥라떼',
#  '#임자있슈',
#  '#흑임자티라미슈',
#  '#앙트리',
#  '#양갱',
#  '#cafe',
#  '#cafegram',
#  '#dessert',
#  '#묘사서울',
#  '#pure',
#  '#서울',
#  '#카페',
#  '#cafe',
#  '#카페스타그램',
#  '#cafestagram',
#  '#카페투어',
#  '#크리스마스',
#  '#크리스마스트리',
#  '#성수',
#  '#성수카페',
#  '#어니언',
#  '#어니언카페',
#  '#onion',
#  '#잘가',
#  '#마산',
#  '#아이들',
#  '#내일은',
#  '#월요일',
#  '#출근',
#  '#예쁜여자',
#  '#스테이크',
#  '#긴머리',
#  '#영화',
#  '#일상룩',
#  '#노가리',
#  '#성수',
#  '#구월동',
#  '#성수대교',
#  '#여행',
#  '#한남동맛집',
#  '#선릉역',
#  '#여행중',
#  '#출근',
#  '#사진',
#  '#주말일상',
#  '#성수',
#  '#뮤지엄오브컬러',
#  '#멍',
#  '#colors',
#  '#sfactory',
#  '#성수동카페',
#  '#성수',
#  '#애드미네일',
#  '#겨울',
#  '#화려한네일',
#  '#호피네일',
#  '#겨울네일',
#  '#시럽네일',
#  '#깔끔한네일',
#  '#체크네일',
#  '#자개네일',
#  '#시럽그라데이션',
#  '#스와로브스키네일',
#  '#프렌치네일',
#  '#매트네일',
#  '#건대',
#  '#건대네일',
#  '#건대네일샵',
#  '#네일',
#  '#젤네일',
#  '#네일아트',
#  '#젤네일아트',
#  '#건대',
#  '#구의네일',
#  '#구의',
#  '#성수',
#  '#성수네일',
#  '#패디젤',
#  '#패디아트',
#  '#젤패디',
#  '#이달의아트',
#  '#성수',
#  '#서울숲스냅',
#  '#마리에블룸',
#  '#travel',
#  '#travelgram',
#  '#photo',
#  '#iphone7plus',
#  '#photography',
#  '#selfies',
#  '#selfie',
#  '#selstagram',
#  '#wandering',
#  '#성수',
#  '#성수동카페',
#  '#할아버지공장',
#  '#성수',
#  '#카페',
#  '#대림창고',
#  '#분위기좋네',
#  '#이쁜카페',
#  '#여친없으니깐',
#  '#커피도맛있어',
#  '#성수',
#  '#성수카페',
#  '#크리스마스',
#  '#분위기',
#  '#향초',
#  '#성수',
#  '#카페온화',
#  '#성수',
#  '#성수동카페',
#  '#카페온화성수',
#  '#수플레팬케이크',
#  '#카페스타그램',
#  '#카페탐방',
#  '#님께서',
#  '#성수',
#  '#수제화브랜드',
#  '#데일리',
#  '#소통',
#  '#Fashion',
#  '#handmadeshoes',
#  '#인스타그램',
#  '#Instagram',
#  '#옷스타그램',
#  '#미니멀',
#  '#ootd',
#  '#오오티디',
#  '#데일리신발',
#  '#일상',
#  '#sneakers',
#  '#footsell',
#  '#와이드데님',
#  '#Selectshop',
#  '#문스타',
#  '#코스',
#  '#커먼프로젝트',
#  '#Lemaire',
#  '#dailysheos',
#  '#dailyfashion',
#  '#성수동',
#  '#플리징',
#  '#수제화추천',
#  '#첼시부츠',
#  '#성수',
#  '#chosunhwaro',
#  '#맛집',
#  '#먹스타그램',
#  '#먹방',
#  '#푸드스타그램',
#  '#맛스타',
#  '#맛집추천',
#  '#맛집그램',
#  '#먹스타그램',
#  '#먹스타',
#  '#데이트맛집',
#  '#핫플',
#  '#핫플카페',
#  '#핫플레이스',
#  '#맛집투어',
#  '#팔로어',
#  '#팔로잉',
#  '#좋아요',
#  '#foodstagram',
#  '#이태원',
#  '#해방촌',
#  '#청담',
#  '#압구정',
#  '#강남',
#  '#을지로',
#  '#성수',
#  '#한우암소',
#  '#소갈비',
#  '#한우갈비',
#  '#소고기맛집',
#  '#분당소고기',
#  '#성수역',
#  '#성수',
#  '#성수까페',
#  '#바이산',
#  '#피아노연주회',
#  '#스위트피아노수강생들',
#  '#송년모임',
#  '#스위트피아노',
#  '#sweetpiano',
#  '#sweet',
#  '#건대',
#  '#성수',
#  '#뚝섬',
#  '#piano',
#  '#자양동',
#  '#건대스위트피아노',
#  '#건대성인피아노',
#  '#건대직장인피아노',
#  '#건대성인피아노학원',
#  '#성인피아노학원',
#  '#직장인피아노',
#  '#취미피아노',
#  '#성인음악학원',
#  '#음악',
#  '#music',
#  '#맞팔',
#  '#소통',
#  '#일상',
#  '#좋아요',
#  '#pianoclassic',
#  '#뚝섬성인피아노학원',
#  '#취미',
#  '#성수성인피아노학원',
#  '#자양동피아노학원',
#  '#백예린',
#  '#브리즈웨이',
#  '#크리스마스',
#  '#콘서트',
#  '#예린',
#  '#yerinbaek',
#  '#성수',
#  '#블루바이닐',
#  '#bluevinyl',
#  '#브리즈웨이크리스마스에디션',
#  '#yerin',
#  '#concert',
#  '#christmas',
#  '#breezeway',
#  '#yerinbaek',
#  '#sungsu',
#  '#공연',
#  '#performance',
#  '#square',
#  '#뮤지션',
#  '#music',
#  '#musician',
#  '#라이카',
#  '#leica',
#  '#직찍',
#  '#무보정',
#  '#폴더크루',
#  '#폴더',
#  '#뉴발란스',
#  '#뉴발란스703',
#  '#newbalance',
#  '#newbalance703',
#  '#폴더동성로',
#  '#폴더동성로2호점',
#  '#likeforlikes',
#  '#likeforfollow',
#  '#streetstyle',
#  '#highsnobiety',
#  '#fuckyourhype',
#  '#ootd',
#  '#hypebeast',
#  '#like4likes',
#  '#picture',
#  '#dailylook',
#  '#outfit',
#  '#streetwearfashion',
#  '#서면',
#  '#홍대',
#  '#합정',
#  '#성수',
#  '#데일리룩',
#  '#데일리',
#  '#폴더세일',
#  '#슈퍼폴더',
#  '#슈퍼세일',
#  '#대림창고',
#  '#낙원스낵',
#  '#성수',
#  '#성수카페',
#  '#건대',
#  '#얼그레이케익',
#  '#비엔나커피',
#  '#바질페스토피자',
#  '#마약옥수수',
#  '#또먹고싶잖아',
#  '#친구',
#  '#일상',
#  '#애쉬브라운',
#  '#볼륨매직c컬',
#  '#퍼스널컬러',
#  '#건대',
#  '#성수',
#  '#서울숲',
#  '#구의',
#  '#구의미용실',
#  '#건대미용실',
#  '#허쉬컷',
#  '#좋아요',
#  '#레이어드컷',
#  '#빌드펌',
#  '#팔로우',
#  '#선팔',
#  '#단발펌',
#  '#구의역',
#  '#광진구',
#  '#광진구미용실',
#  '#아차산',
#  '#허쉬컷',
#  '#맞팔',
#  '#수능이벤트',
#  '#수능생',
#  '#스타벅스',
#  '#헬스',
#  '#헤드스파',
#  '#때가이르매성수',
#  '#때가이르매',
#  '#뚝섬',
#  '#뚝섬역',
#  '#뚝섬카페',
#  '#뚝섬역카페',
#  '#뚝섬맛집',
#  '#뚝섬역맛집',
#  '#서울숲',
#  '#서울숲카페',
#  '#성수',
#  '#성수역',
#  '#성수카페',
#  '#성수역카페',
#  '#카페스타그램',
#  '#카페추천',
#  '#서울카페',
#  '#건대',
#  '#건대카페',
#  '#건대입구역',
#  '#건대입구역카페',
#  '#카페대관',
#  '#쇼핑몰대관',
#  '#대관문의',
#  '#cafe',
#  '#긴머리',
#  '#레이어드컷',
#  '#s컬펌',
#  '#전체염색',
#  '#뿌리염색',
#  '#매트',
#  '#DM환영',
#  '#준오헤어나희',
#  '#준오헤어',
#  '#건대준오헤어1호점',
#  '#헤어모델구함',
#  '#염색',
#  '#커트',
#  '#펌',
#  '#c컬펌',
#  '#s컬펌',
#  '#머리잘하는미용실',
#  '#염색모델',
#  '#커트모델',
#  '#펌모델',
#  '#뿌리펌',
#  '#매트브라운염색',
#  '#베이지브라운염색',
#  '#다크브라운염색',
#  '#성수역미용실',
#  '#건대역미용실',
#  '#건대',
#  '#성수',
#  '#뚝섬',
#  '#한양대',
#  '#왕십리',
#  '#일상',
#  '#일상스타그램',
#  '#일상룩',
#  '#인친',
#  '#daily',
#  '#ootd',
#  '#instargram',
#  '#셀스타',
#  '#셀카',
#  '#following',
#  '#셀스타그램',
#  '#데일리',
#  '#맞팔해요',
#  '#인친환영',
#  '#선팔하면맞팔',
#  '#팔로워',
#  '#좋반',
#  '#좋반테러',
#  '#맞팔',
#  '#likeforfollow',
#  '#like4like',
#  '#follow4follow',
#  '#likesforlike',
#  '#followback',
#  '#홍대',
#  '#합정',
#  '#성수',
#  '#전시회',
#  '#데일리',
#  '#데이트',
#  '#혼술',
#  '#용싸롱',
#  '#블루보틀',
#  '#대림창고',
#  '#성수연방',
#  '#에스팩토리',
#  '#성수',
#  '#성수동',
#  '#성수동핫플',
#  '#성수동술집',
#  '#성수역술집',
#  '#건대술집',
#  '#뚝섬역혼술',
#  '#뚝섬역술집',
#  '#서울숲술집',
#  '#서울숲혼술',
#  '#성수동혼술',
#  '#성수역혼술',
#  '#건대혼술',
#  '#성수역맛집',
#  '#성수동맛집',
#  '#성수동이자카야',
#  '#조용한',
#  '#분위기',
#  '#나만알고싶은곳',
#  '#하이볼',
#  '#성수',
#  '#드로잉카페',
#  '#페인팅',
#  '#취미생활',
#  '#문화생활',
#  '#힐링',
#  '#일상',
#  '#소통',
#  '#셀카',
#  '#seongsu',
#  '#seongsucafe',
#  '#drawing',
#  '#daily',
#  '#painting',
#  '#hobby',
#  '#healthylifestyle',
#  '#selfie',
#  '#fff',
#  '#f4f',
#  '#l4l',
#  '#보일러룸',
#  '#boilerroom',
#  '#boiler',
#  '#보일러',
#  '#성수에스팩토리',
#  '#성수역',
#  '#성수sfactory',
#  '#성수s팩토리',
#  '#성수',
#  '#성수동',
#  '#성수동맛집',
#  '#일상',
#  '#소통',
#  '#맞팔',
#  '#얼스타그램',
#  '#셀스타그램',
#  '#친구',
#  '#친스타그램',
#  '#맛집',
#  '#성수',
#  '#성수다락',
#  '#파스타',
#  '#오므라이스',
#  '#목살스테이크',
#  '#트러플감자튀김',
#  '#selfie',
#  '#daily',
#  '#폴더크루',
#  '#폴더',
#  '#나이키',
#  '#nike',
#  '#airmax95',
#  '#폴더동성로',
#  '#폴더동성로2호점',
#  '#likeforlikes',
#  '#likeforfollow',
#  '#streetstyle',
#  '#highsnobiety',
#  '#fuckyourhype',
#  '#ootd',
#  '#hypebeast',
#  '#like4likes',
#  '#picture',
#  '#dailylook',
#  '#outfit',
#  '#streetwearfashion',
#  '#서면',
#  '#홍대',
#  '#합정',
#  '#성수',
#  '#데일리룩',
#  '#데일리',
#  '#폴더세일',
#  '#슈퍼폴더',
#  '#슈퍼세일',
#  '#건대데이트',
#  '#건대',
#  '#성수동맛집',
#  '#성수',
#  '#뚝섬',
#  '#꼼보포차',
#  '#데이트',
#  '#소주',
#  '#소맥',
#  '#맥주',
#  '#카페',
#  '#카페오롯',
#  '#해남식당',
#  '#데일리',
#  '#일상',
#  '#보일러룸',
#  '#보일러룸서울',
#  '#boilerroom',
#  '#성수',
#  '#성수동',
#  '#에스팩토리',
#  '#연말파티',
#  '#서울',
#  '#성수',
#  '#성수소문난감자탕',
#  '#감자탕',
#  '#맛집',
#  '#계속',
#  '#추가',
#  '#먹방',
#  '#광명',
#  '#명장제과',
#  '#빵',
#  '#커피',
#  '#맛나네',
#  '#먹방',
#  '#3인방',
#  '#음식은',
#  '#손맛',
#  '#재밌당',
#  '#내년에',
#  '#또만나',
#  '#크리스마스',
#  '#미리크리스마스',
#  '#감자모임',
#  '#감자파티',
#  '#해피감자스마스',
#  '#성수',
#  '#성수역',
#  '#파티룸',
#  '#이마트',
#  '#배달',
#  '#행복해',
#  '#사진전',
#  '#전시회',
#  '#성수',
#  '#비컨',
#  '#BEACON',
#  '#전시회',
#  '#뮤지엄오브컬러',
#  '#전시회추천',
#  '#셀피',
#  '#셀카',
#  '#인물사진',
#  '#일반인모델',
#  '#museumofcolor',
#  '#뮤지엄오브컬러전시회',
#  '#사진',
#  '#전시',
#  '#사진스타그램',
#  '#셀카스타그램',
#  '#selfie',
#  '#전시',
#  '#성수',
#  '#성수역전시',
#  '#성수전시',
#  '#크리스마스엽서',
#  '#심미안',
#  '#성수동',
#  '#vintage',
#  '#빈티지샵',
#  '#성수동심미안',
#  '#핸드메이드샵',
#  '#편집샵',
#  '#스너퍼',
#  '#양초',
#  '#캔들',
#  '#엔틱',
#  '#엔틱소품',
#  '#싱글라이프',
#  '#성수',
#  '#성수동편집샵',
#  '#simmian',
#  '#뮤지엄오브컬러',
#  '#뚝섬',
#  '#성수',
#  '#전시회',
#  '#color',
#  '#서울전시회',
#  '#이색전시회',
#  '#올해의컬러',
#  '#일상',
#  '#seoul',
#  '#전시회추천',
#  '#예술',
#  '#그림',
#  '#그림스타그램',
#  '#성수동',
#  '#에스팩토리',
#  '#에스팩토리성수',
#  '#크리스마스',
#  '#댓글반사',
#  '#댓글소통',
#  '#선팔',
#  '#맞팔',
#  '#반사',
#  '#좋반',
#  '#좋아요',
#  '#선팔맞팔',
#  '#인친',
#  '#좋아요반사',
#  '#소통',
#  '#팔로우',
#  '#한강',
#  '#데일리',
#  '#데일리룩',
#  '#셀피',
#  '#맛집',
#  '#먹스타그램',
#  '#헬스타그램',
#  '#seoul',
#  '#koreastyle',
#  '#kpop',
#  '#홍대',
#  '#이태원',
#  '#성수',
#  '#바이크스타그램',
#  '#라이더',
#  '#반스',
#  '#성수동',
#  '#성수',
#  '#힌스',
#  '#이터널',
#  '#일상',
#  '#소통',
#  '#휴무',
#  '#감동',
#  '#성수',
#  '#뚝섬카페',
#  '#카페차',
#  '#ㅊa',
#  '#달로나밀크티',
#  '#밀크티',
#  '#플레인스콘',
#  '#맛있당',
#  '#언니랑',
#  '#미주랑',
#  '#추억',
#  '#2016년',
#  '#어느더운날',
#  '#왕십리',
#  '#역사공원',
#  '#분수',
#  '#아빠와함께',
#  '#점심',
#  '#타코벨',
#  '#배가불러서그런가',
#  '#엄청',
#  '#신났넹',
#  '#서울숲',
#  '#뚝섬',
#  '#성수',
#  '#성수동',
#  '#뚝섬역',
#  '#쌍둥이',
#  '#일상스타그램',
#  '#반지만들기',
#  '#우정링',
#  '#성수',
#  '#다로베',
#  '#크리스마스풍선',
#  '#크리스마스파티',
#  '#벌룬프로젝트성동점',
#  '#커스텀풍선',
#  '#커스텀벌룬',
#  '#파티풍선',
#  '#파티용품',
#  '#산타풍선',
#  '#balloonproject',
#  '#성수',
#  '#보일러룸',
#  '#boilerroom',
#  '#boiler',
#  '#보일러',
#  '#성수에스팩토리',
#  '#성수역',
#  '#성수sfactory',
#  '#성수s팩토리',
#  '#성수',
#  '#성수동',
#  '#호피가방',
#  '#호피숄더백',
#  '#호피복조리',
#  '#데일리백',
#  '#가방스타그램',
#  '#가방추천',
#  '#daily',
#  '#instadaily',
#  '#instapic',
#  '#맛저',
#  '#루미스파',
#  '#visitkorea',
#  '#seongsudong',
#  '#wallpainting',
#  '#janeaustenquote',
#  '#janeausten',
#  '#bemyself',
#  '#lovemyself',
#  '#travelholic',
#  '#ig',
#  '#insta',
#  '#성수',
#  '#성수동',
#  '#Repost',
#  '#색다른면',
#  '#성수',
#  '#한양대pt',
#  '#왕십리pt',
#  '#트레이너',
#  '#pt문의',
#  '#pt',
#  '#남자트레이너',
#  '#여자트레이너',
#  '#운동하는남자',
#  '#운동하는여자',
#  '#왕십리',
#  '#한양대',
#  '#힙업',
#  '#운동',
#  '#헬스',
#  '#연예인pt',
#  '#다이어트',
#  '#바디프로필',
#  '#인친',
#  '#일상',
#  '#얼스타그램',
#  '#셀피',
#  '#셀카',
#  '#데일리',
#  '#데일리룩',
#  '#daily',
#  '#성수',
#  '#인친',
#  '#맞팔',
#  '#소통',
#  '#20191222',
#  '#도치피자',
#  '#도치피자',
#  '#피자맛집',
#  '#성수맛집',
#  '#성수동',
#  '#성수',
#  '#피자맛집',
#  '#파스타맛집',
#  '#먹스타그램',
#  '#존맛탱',
#  '#성수',
#  '#성수대림창고',
#  '#크리스마스',
#  '#트리',
#  '#성수연방',
#  '#성수',
#  '#대림창고',
#  '#아크앤북',
#  '#성수투어',
#  '#mirandahwang',
#  '#미란다황',
#  '#귀걸이',
#  '#연말모임',
#  '#파티',
#  '#클럽',
#  '#모임',
#  '#약속',
#  '#데이트',
#  '#커플',
#  '#저녁',
#  '#일요일',
#  '#홍대',
#  '#이태원',
#  '#성수',
#  '#동성로',
#  '#paris',
#  '#party',
#  '#인플루언서',
#  '#소통',
#  '#성수다락',
#  '#서울전시',
#  '#12월전시추천',
#  '#성수동',
#  '#건대입구',
#  '#성수데이트',
#  '#성수카페',
#  '#서울크리스마스',
#  '#크리스마스',
#  '#서울맛집',
#  '#연말데이트',
#  '#서울연말데이트',
#  '#서울데이트',
#  '#사진찍기좋은곳',
#  '#성수핫플',
#  '#뚝섬',
#  '#실내데이트',
#  '#실내나들이',
#  '#일상',
#  '#성수맛집',
#  '#서울숲',
#  '#2020',
#  '#성수',
#  '#미술전시',
#  '#전시회추천',
#  '#서울핫플',
#  '#서울데이트코스',
#  '#스냅사진',
#  '#사진',
#  '#스모크피기',
#  '#성수동',
#  '#배달의민족',
#  '#요기요테크아웃',
#  '#크리스마스',
#  '#훈제바베큐',
#  '#크리스마스',
#  '#뚝섬',
#  '#서울숲',
#  '#성수',
#  '#뚝섬',
#  '#성수',
#  '#건대입구',
#  '#달고나밀크티',
#  '#ㅊa',
#  '#전참시',
#  '#이영자맛집',
#  '#성수',
#  '#성수카페',
#  '#성수연방',
#  '#실패',
#  '#어디로가야하죠아저씨',
#  '#파랑새전시회',
#  '#성수',
#  '#성수',
#  '#성수맛집',
#  '#레귤러',
#  '#스테이크',
#  '#파스타',
#  '#서울',
#  '#광주',
#  '#광진구',
#  ...]

# %%
c = Counter(insta_str)

# %%
c.most_common(50)
# Out:
# [('#성수', 568),
#  ('#일상', 124),
#  ('#데일리', 89),
#  ('#daily', 80),
#  ('#서울숲', 76),
#  ('#성수동', 75),
#  ('#ootd', 74),
#  ('#맞팔', 73),
#  ('#뚝섬', 72),
#  ('#좋아요', 72),
#  ('#카페', 69),
#  ('#selfie', 68),
#  ('#소통', 58),
#  ('#건대', 53),
#  ('#셀카', 53),
#  ('#성수카페', 51),
#  ('#크리스마스', 46),
#  ('#셀스타그램', 45),
#  ('#홍대', 44),
#  ('#데일리룩', 44),
#  ('#서울', 43),
#  ('#팔로우', 43),
#  ('#셀피', 42),
#  ('#먹스타그램', 41),
#  ('#선팔', 39),
#  ('#성수동카페', 38),
#  ('#성수맛집', 32),
#  ('#맛집', 32),
#  ('#cafe', 31),
#  ('#주말', 30),
#  ('#성수동맛집', 30),
#  ('#성수역', 28),
#  ('#강남', 28),
#  ('#dailylook', 28),
#  ('#뮤지엄오브컬러', 26),
#  ('#오오티디', 26),
#  ('#좋반', 26),
#  ('#카페투어', 25),
#  ('#좋아요반사', 25),
#  ('#사진', 24),
#  ('#왕십리', 24),
#  ('#블루보틀', 24),
#  ('#instagood', 24),
#  ('#이태원', 23),
#  ('#카페스타그램', 23),
#  ('#직장인', 23),
#  ('#f4f', 22),
#  ('#데이트', 20),
#  ('#합정', 20),
#  ('#전시회', 20)]

# %%
insta_df.to_csv(keyword + '.csv',mode='w', encoding='euc-kr')
